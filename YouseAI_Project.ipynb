# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("FinanceData.csv")

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.shape
# Out:
# (8950, 18)

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Out of 18 features - The data has missing values only in 2 features :- 
# Where we can see in Minimum_Payments feature there are 313 values missing.
# In credit_limit feature there is a single value missing.

# %%
data['CUST_ID'].unique()
# Out:
# array(['C10001', 'C10002', 'C10003', ..., 'C19188', 'C19189', 'C19190'],
#       dtype=object)

# %%
data['CUST_ID'].nunique()
# Out:
# 8950

# %%
skewness  = data['MINIMUM_PAYMENTS'].skew()

# %%
skewness
# Out:
# 13.622796994677456

# %%
# The data is right skewed for less missing values still we can use the mean method to fill it
# but in case of minimum payments there are more missing values so we can't directly consider using mean as the data is rightly skewed.

# %%
data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].mean(), inplace=True)

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          0
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data['log_MINIMUM_PAYMENTS'] = np.log1p(data['MINIMUM_PAYMENTS'])

# %%
print(data['log_MINIMUM_PAYMENTS'].skew())
# Out:
# 0.24993338691371428

# %%
data['log_MINIMUM_PAYMENTS'].fillna(data['log_MINIMUM_PAYMENTS'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          0
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# log_MINIMUM_PAYMENTS                  0
# dtype: int64

# %%
print(data['MINIMUM_PAYMENTS'].isna().sum())
# Out:
# 313

# %%
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# log_MINIMUM_PAYMENTS                0
# dtype: int64

# %%
#now there are no missing values - as earlier there might be a problem of Nan Values

# %%
sns.boxplot(data=data[['ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']])
plt.title('Distribution of One-off vs Installment Purchases')
plt.show()

# %%
sns.violinplot(data=data[['ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']])
plt.title('Violin Plot: One-off vs Installment Purchases')
plt.show()

# %%
max(data['INSTALLMENTS_PURCHASES'])
# Out:
# 22500.0

# %%
max(data['ONEOFF_PURCHASES'])
# Out:
# 40761.25

# %%
plt.scatter(data['CREDIT_LIMIT'], data['PURCHASES'], color='blue', alpha=0.6)
plt.xlabel('Credit Limit')
plt.ylabel('Purchases')
plt.title('Credit Limit vs Purchases')
plt.show()

# %%
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.drop(columns=['CUST_ID'],inplace = True)

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters = i)
    km.fit_predict(data)
    wcss.append(km.inertia_)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [393152993893.59656,
#  279341225127.46375,
#  232837871829.7193,
#  206848141575.87796,
#  182177531240.19373,
#  163112216982.96124,
#  145222144410.2958,
#  132892603354.29742,
#  124180274621.2727,
#  117128040403.54622]

# %%
plt.plot(range(1,11),wcss)

# %%
# N-clusters = 10 , lets consider to be 10

# %%
X = data.iloc[:,:].values
km = KMeans(n_clusters=7)
y_means = km.fit_predict(X)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(X, y_means)

# %%
score
# Out:
# 0.3704140622625005

# %%
y_means
# Out:
# array([0, 4, 4, ..., 0, 0, 0], dtype=int32)

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1])
plt.scatter(X[y_means == 1,0],X[y_means == 1,1])
plt.scatter(X[y_means == 2,0],X[y_means == 2,1])
plt.scatter(X[y_means == 3,0],X[y_means == 3,1])
plt.scatter(X[y_means == 4,0],X[y_means == 4,1])
plt.scatter(X[y_means == 5,0],X[y_means == 5,1])
plt.scatter(X[y_means == 6,0],X[y_means == 6,1])
plt.scatter(X[y_means == 7,0],X[y_means == 7,1])
plt.scatter(X[y_means == 8,0],X[y_means == 8,1])
plt.scatter(X[y_means == 9,0],X[y_means == 9,1])

# %%
# We can see here K means clustering is very sensitive to outliers
# In any way it will try to form clusters and even try to bring the noise in a cluster.

# %%
plt.scatter(data.iloc[:, 0], data.iloc[:,-6 ], c=clusters, cmap='plasma')
plt.title('Clustering')
plt.xlabel('Balance')
plt.ylabel('Credit Limit')
plt.colorbar()
plt.show()

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
plt.scatter(data.iloc[:, -6], data.iloc[:,0 ], c=clusters, cmap='plasma')
plt.title('Clustering')
plt.xlabel('Credit Limit')
plt.ylabel('Balance')
plt.colorbar()
plt.show()

# %%
score = silhouette_score(X, y_means)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_features = pca.fit_transform(data)

plt.scatter(pca_features[:, 0], pca_features[:, 1])
plt.title('PCA Components for Clustering')
plt.show()

# %%
plt.scatter(data.iloc[:, -4], data.iloc[:,-5 ], c=clusters, cmap='plasma')
plt.title('DBSCAN Clustering')
plt.xlabel('Payments')
plt.ylabel('Minimum Payments')
plt.colorbar()
plt.show()

# %%
score = silhouette_score(X, y_means)

# %%
plt.scatter(data.iloc[:, 10], data.iloc[:,-8], c=clusters, cmap='plasma')
plt.title('DBSCAN Clustering')
plt.xlabel('Cash Advanced Transactions')
plt.ylabel('Purchases')
plt.colorbar()
plt.show()

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
data['Ticket_Size']= data['PURCHASES']/data['PURCHASES_TRX']

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
dbscan = DBSCAN(eps=0.5, min_samples=1400) 
clusters = dbscan.fit_predict(X)
data['Cluster'] = clusters
plt.scatter(data['ONEOFF_PURCHASES'], data['INSTALLMENTS_PURCHASES'], c=data['Cluster'], cmap='plasma')
plt.xlabel('OneOff Purchases')
plt.ylabel('Installment Purchases')
plt.title('DBSCAN Clustering of One-Off vs Installment Purchases')
plt.show()

# %%
if len(set(clusters)) > 1 and -1 not in set(clusters):
    score = silhouette_score(X, clusters)
    print(f'Silhouette Score: {score}')
else:
    print("Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise")
# Out:
# Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5) 
clusters = dbscan.fit_predict(X)
data['Cluster'] = clusters
plt.scatter(data['Ticket_Size'], data['PURCHASES'], c=data['Cluster'], cmap='spring')
plt.xlabel('Ticket Size')
plt.ylabel('Installment Purchases')
plt.title('DBSCAN Clustering of One-Off vs Installment Purchases')
plt.show()

# %%
if len(set(clusters)) > 1 and -1 not in set(clusters):
    score = silhouette_score(X, clusters)
    print(f'Silhouette Score: {score}')
else:
    print("Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise")
# Out:
# Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise

# %%
non_zero_cash_adv = (data['CASH_ADVANCE'] != 0).sum()

# %%
non_zero_cash_adv
# Out:
# 4322

# %%
dbscan = DBSCAN(eps=0.5, min_samples=19) 
clusters = dbscan.fit_predict(X)
data['Cluster'] = clusters
plt.scatter(data['CASH_ADVANCE'], data['PURCHASES'], c=data['Cluster'], cmap='pink')
plt.xlabel('Cash Advanced paid')
plt.ylabel('Installment Purchases')
plt.title('DBSCAN Clustering of One-Off vs Installment Purchases')
plt.show()

# %%
if len(set(clusters)) > 1 and -1 not in set(clusters):
    score = silhouette_score(X, clusters)
    print(f'Silhouette Score: {score}')
else:
    print("Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise")
# Out:
# Silhouette Score cannot be calculated as their is only single cluster or there are all points as noise

# %%
dbscan = DBSCAN(eps=0.7, min_samples=36) 
clusters = dbscan.fit_predict(X)
data['Cluster'] = clusters
plt.scatter(data['CASH_ADVANCE'], data['PURCHASES'], c=data['Cluster'], cmap='rainbow')
plt.xlabel('Cash Advanced paid')
plt.ylabel('Installment Purchases')
plt.title('DBSCAN Clustering of One-Off vs Installment Purchases')
plt.show()

# %%
print(np.isinf(data).sum())
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# log_MINIMUM_PAYMENTS                0
# Ticket_Size                         3
# Cluster                             0
# dtype: int64

# %%
print(np.any(np.abs(data) > 1e10))
# Out:
# True

# %%
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')  
data_imputed = imputer.fit_transform(data)

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_imputed)

# %%
scaled_data
# Out:
# array([[2.14779454e-03, 8.18182000e-01, 1.94536779e-03, ...,
#         4.38874032e-01, 7.97436612e-03, 0.00000000e+00],
#        [1.68169097e-01, 9.09091000e-01, 0.00000000e+00, ...,
#         6.20012622e-01, 9.26985233e-03, 0.00000000e+00],
#        [1.31026136e-01, 1.00000000e+00, 1.57662475e-02, ...,
#         5.72302658e-01, 1.07713848e-02, 0.00000000e+00],
#        ...,
#        [1.22871936e-03, 8.33333000e-01, 2.94456089e-03, ...,
#         3.92422758e-01, 4.82808582e-03, 0.00000000e+00],
#        [7.06688341e-04, 8.33333000e-01, 0.00000000e+00, ...,
#         3.58113730e-01, 9.26985233e-03, 0.00000000e+00],
#        [1.95717777e-02, 6.66667000e-01, 2.22932216e-02, ...,
#         3.98481571e-01, 7.94638206e-03, 0.00000000e+00]])

# %%
data_h = data.iloc[:,:]

# %%
data_h
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
data.fillna(data.median(), inplace=True)

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize = (10,7))
plt.title("Customer Dendrograms")
dend = shc.dendrogram(shc.linkage(data, method = 'ward'))

# %%
from sklearn.cluster import AgglomerativeClustering 
cluster = AgglomerativeClustering( n_clusters = 5 , affinity = 'euclidean' , linkage='ward')
labels_=cluster.fit_predict(data)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
labels_
# Out:
# array([3, 0, 1, ..., 3, 3, 3])

# %%
plt.figure(figsize=(10,7))
plt.scatter(data.iloc[:,3] , data.iloc[:,4] , c=cluster.labels_ , cmap = 'plasma')

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
def categorize_credit_limit(value):
    if value <= 500:
        return '0-500'
    elif 500 < value <= 1000:
        return '500-1000'
    elif 1000 < value <= 1500:
        return '1000-1500'
    elif 1500 < value <= 5000:
        return '1500-5000'
    elif 5000 < value <= 10000:
        return '5000-10000'
    else:
        return '10000 above'


data['Credit_Limit_Range'] = data['CREDIT_LIMIT'].apply(categorize_credit_limit)


print(data[['CREDIT_LIMIT', 'Credit_Limit_Range']].head())
# Out:
#    CREDIT_LIMIT Credit_Limit_Range
# 0        1000.0           500-1000
# 1        7000.0         5000-10000
# 2        7500.0         5000-10000
# 3        7500.0         5000-10000
# 4        1200.0          1000-1500

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
credit_order = ['0-500', '500-1000', '1000-1500', '1500-5000', '5000-10000', '10000 above']
data['Credit_Limit_Range'] = pd.Categorical(data['Credit_Limit_Range'], categories=credit_order, ordered=True)
plt.figure(figsize=(10,7))
plt.scatter(data['Credit_Limit_Range'].cat.codes, data['PURCHASES'], c=clusters, cmap='plasma')
plt.title('DBSCAN Clustering')
plt.xlabel('Credit Limit Range')
plt.ylabel('Purchases')
plt.colorbar()
plt.show()

# %%
max(data['BALANCE'])
# Out:
# 19043.13856

# %%
def categorize_balance(value):
    if value <= 500:
        return '0-500'
    elif 500 < value <= 5000:
        return '500-5000'
    elif 5000 < value <= 10000:
        return '5000-1000'
    else:
        return '10000 above'


data['Balance_value'] = data['BALANCE'].apply(categorize_balance)


print(data[['BALANCE', 'Balance_value']].head())
# Out:
#        BALANCE Balance_value
# 0    40.900749         0-500
# 1  3202.467416      500-5000
# 2  2495.148862      500-5000
# 3  1666.670542      500-5000
# 4   817.714335      500-5000

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
balance_order = ['0-500', '500-5000', '5000-10000','10000 above']
data['Balance_value'] = pd.Categorical(data['Balance_value'], categories=credit_order, ordered=True)
plt.figure(figsize=(10,7))
plt.scatter(data['TENURE'], data['BALANCE'], c=clusters, cmap='plasma')
plt.title('DBSCAN Clustering')
plt.xlabel('TENURE')
plt.ylabel('Balance')
plt.colorbar()
plt.show()
